# %%
# !pip install quarto-cli

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !quarto render "/content/drive/MyDrive/Colab Notebooks/Quarto_Assignment.ipynb"
# Out:
# pandoc
#   to: html
#   output-file: Quarto_Assignment.html
#   standalone: true
#   embed-resources: true
#   section-divs: true
#   html-math-method: mathjax
#   wrap: none
#   default-image-extension: png
#   toc: true
#   toc-depth: 2
#
# metadata
#   document-css: false
#   link-citations: true
#   date-format: long
#   lang: en
#   title: 'A Tale of Two Worlds: Child Well-being Across Economic and Healthcare Landscapes'
#   author: Pranitha Bangera
#   theme: cosmo
#
# Output created: Quarto_Assignment.html
